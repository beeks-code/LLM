# %%
import torch

# %%
### initing random ids
input_token_ids=torch.tensor([2,3,5])

# %%
vocabulary_size=10
n_dim=6 ## dimention of embedding

# %%
embedding=torch.nn.Embedding(vocabulary_size,n_dim)
embedding.weight.size()
# Out:
# torch.Size([10, 6])

# %%
## lookup table for 10 words
embedding.weight
# Out:
# Parameter containing:
# tensor([[ 2.1692,  0.4233, -0.4083,  0.3531,  0.8930,  0.8867],
#         [ 0.0189, -0.3106, -0.8979, -0.2768, -0.6497, -1.1272],
#         [-0.4554,  2.0863,  0.7669, -1.0232, -0.3053,  0.3712],
#         [ 1.5846, -0.5892,  0.7334,  1.0841, -1.6037,  0.0470],
#         [ 1.0653, -0.3230,  0.5668,  0.4247,  0.3777,  0.1624],
#         [-1.2800,  1.7688, -0.1462, -0.6670,  1.3219, -0.4228],
#         [ 0.5753,  0.9784, -0.4098,  1.5596, -0.7392, -0.2040],
#         [ 0.0242,  0.5518,  1.1410, -1.1844, -1.2644,  0.3863],
#         [ 0.9484,  1.8924,  0.3339, -0.7553, -0.4734, -0.1744],
#         [-1.1889, -0.3598, -1.8546, -1.9863,  0.1146, -1.9376]],
#        requires_grad=True)

# %%
embedding.weight[input_token_ids]
# Out:
# tensor([[-0.4554,  2.0863,  0.7669, -1.0232, -0.3053,  0.3712],
#         [ 1.5846, -0.5892,  0.7334,  1.0841, -1.6037,  0.0470],
#         [-1.2800,  1.7688, -0.1462, -0.6670,  1.3219, -0.4228]],
#        grad_fn=<IndexBackward0>)
